# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from random import randint, uniform,random

# %% [markdown]
# # Muestras para una distribucion normal

# %%
def distribucion_normal(b,n=12):
    sumatoria = 0
    array = []
    for _ in range(0,n):
        aleatorio = randint(-b,b)
        array.append(aleatorio)
        sumatoria = sumatoria + aleatorio
        
    return array,1/2*sumatoria

# %% [markdown]
# # Muestras para una distribucion Triangular

# %%
def distribucion_triangular(b,n=12):
    array = []
    for _ in range(0,n):
        aleatorio =math.sqrt(6)/2*randint(-b,b)+randint(-b,b)
        array.append(aleatorio)

    return array

# %%
b = 20
datos,suma_ = distribucion_normal(b,n=20)
array_datos = distribucion_triangular(b,20)

cuenta, cajas, ignorar = plt.hist(datos, b)
plt.xlabel('valores')
plt.title('Muestra de distribucion Gausiana')
plt.show()

# %%
cuenta, cajas, ignorar = plt.hist(array_datos, b)
plt.xlabel('valores')
plt.title('Muestra de distribucion Triangular')
plt.show()

# %% [markdown]
# # Prueba 10 000
# b = 20
# n = 10000
# datos,suma_ = distribucion_normal(b,n)
# array_datos = distribucion_triangular(b,n)

# %%
b = 20
datos,suma_ = distribucion_normal(b,n=10000)
array_datos = distribucion_triangular(b,10000)

# %%
cuenta, cajas, ignorar = plt.hist(datos, b)
plt.xlabel('valores')
plt.title('Muestra de distribucion Gausiana')
plt.show()

# %%
cuenta, cajas, ignorar = plt.hist(array_datos, b)
plt.xlabel('valores')
plt.title('Muestra de distribucion Triangular')
plt.show()

# %% [markdown]
# # Prueba 1 000 000

# %%
b = 20

datos,suma_ = distribucion_normal(b,n)
array_datos = distribucion_triangular(b,n)

# %%
cuenta, cajas, ignorar = plt.hist(datos, b)
plt.xlabel('valores')
plt.title('Muestra de distribucion Gausiana')
plt.show()

# %%
cuenta, cajas, ignorar = plt.hist(array_datos, b)
plt.xlabel('valores')
plt.title('Muestra de distribucion Triangular')
plt.show()

# %% [markdown]
# # Prueba 100 000

# %%
b = 20
n = 100000
datos,suma_ = distribucion_normal(b,n)
array_datos = distribucion_triangular(b,n)

# %%
cuenta, cajas, ignorar = plt.hist(datos, b)
plt.xlabel('valores')
plt.title('Muestra de distribucion Gausiana')
plt.show()

# %%
cuenta, cajas, ignorar = plt.hist(array_datos, b)
plt.xlabel('valores')
plt.title('Muestra de distribucion Triangular')
plt.show()
